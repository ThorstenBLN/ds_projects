# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read data into Dataframe
df = pd.read_excel('../data/gapminder_lifeexpectancy.xlsx', index_col = 0)

# %%
# plot scatterplot
plt.xlabel('LE 1800')
plt.ylabel('LE 2015')
plt.axis([22.5, 50, 22.5, 85])
plt.scatter(df[1800], df[2015])
