# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## 1. Load small MovieLens-dataset

# %%
user_rating_init = pd.read_csv("./data/ml-latest-small/ratings.csv",index_col=1,)
user_rating_init.reset_index(inplace=True)
user_rating_init.drop(['timestamp'], axis=1 , inplace=True)
user_rating_init
# Out:
#         movieId  userId  rating
# 0             1       1     4.0
# 1             3       1     4.0
# 2             6       1     4.0
# 3            47       1     5.0
# 4            50       1     5.0
# ...         ...     ...     ...
# 100831   166534     610     4.0
# 100832   168248     610     5.0
# 100833   168250     610     5.0
# 100834   168252     610     5.0
# 100835   170875     610     3.0
#
# [100836 rows x 3 columns]

# %% [markdown]
# ## 2. Edit data

# %% [markdown]
# ### 2.1 Add movie titles

# %%
# pivot the table
user_item_init = pd.pivot(data=user_rating_init,
                index='userId',
                columns='movieId',
                values='rating')
user_item_init
# Out:
# movieId  1       2       3       4       5       6       7       8       \
# userId
# 1           4.0     NaN     4.0     NaN     NaN     4.0     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5           4.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 606         2.5     NaN     NaN     NaN     NaN     NaN     2.5     NaN
# 607         4.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 608         2.5     2.0     2.0     NaN     NaN     NaN     NaN     NaN
# 609         3.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 610         5.0     NaN     NaN     NaN     NaN     5.0     NaN     NaN
#
# movieId  9       10      ...  193565  193567  193571  193573  193579  193581  \
# userId                   ...
# 1           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# ...         ...     ...  ...     ...     ...     ...     ...     ...     ...
# 606         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 607         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 608         NaN     4.0  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 609         NaN     4.0  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 610         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  193583  193585  193587  193609
# userId
# 1           NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN
# 5           NaN     NaN     NaN     NaN
# ...         ...     ...     ...     ...
# 606         NaN     NaN     NaN     NaN
# 607         NaN     NaN     NaN     NaN
# 608         NaN     NaN     NaN     NaN
# 609         NaN     NaN     NaN     NaN
# 610         NaN     NaN     NaN     NaN
#
# [610 rows x 9724 columns]

# %%
# load the movie titles and genres into a dataframe
movie_genre = pd.read_csv("./data/ml-latest-small/movies.csv",index_col=1,)
# change index from title to movieId
movie_genre.reset_index(inplace=True)
movie_genre.set_index('movieId',inplace=True)

# %%
# Merge the dataframes on movieId and subsitute movieId with movie title
user_item = pd.merge(movie_genre, user_item_init.T, left_index=True, right_index=True)
user_item.drop('genres', inplace=True, axis=1)
user_item.reset_index(inplace=True, drop=True)
user_item = user_item.set_index('title').T
user_item.index.name = 'userId'
user_item
# Out:
# title   Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# userId
# 1                    4.0             NaN                      4.0
# 2                    NaN             NaN                      NaN
# 3                    NaN             NaN                      NaN
# 4                    NaN             NaN                      NaN
# 5                    4.0             NaN                      NaN
# ...                  ...             ...                      ...
# 606                  2.5             NaN                      NaN
# 607                  4.0             NaN                      NaN
# 608                  2.5             2.0                      2.0
# 609                  3.0             NaN                      NaN
# 610                  5.0             NaN                      NaN
#
# title   Waiting to Exhale (1995)  Father of the Bride Part II (1995)  \
# userId
# 1                            NaN                                 NaN
# 2                            NaN                                 NaN
# 3                            NaN                                 NaN
# 4                            NaN                                 NaN
# 5                            NaN                                 NaN
# ...                          ...                                 ...
# 606                          NaN                                 NaN
# 607                          NaN                                 NaN
# 608                          NaN                                 NaN
# 609                          NaN                                 NaN
# 610                          NaN                                 NaN
#
# title   Heat (1995)  Sabrina (1995)  Tom and Huck (1995)  Sudden Death (1995)  \
# userId
# 1               4.0             NaN                  NaN                  NaN
# 2               NaN             NaN                  NaN                  NaN
# 3               NaN             NaN                  NaN                  NaN
# 4               NaN             NaN                  NaN                  NaN
# 5               NaN             NaN                  NaN                  NaN
# ...             ...             ...                  ...                  ...
# 606             NaN             2.5                  NaN                  NaN
# 607             NaN             NaN                  NaN                  NaN
# 608             NaN             NaN                  NaN                  NaN
# 609             NaN             NaN                  NaN                  NaN
# 610             5.0             NaN                  NaN                  NaN
#
# title   GoldenEye (1995)  ...  Gintama: The Movie (2010)  \
# userId                    ...
# 1                    NaN  ...                        NaN
# 2                    NaN  ...                        NaN
# 3                    NaN  ...                        NaN
# 4                    NaN  ...                        NaN
# 5                    NaN  ...                        NaN
# ...                  ...  ...                        ...
# 606                  NaN  ...                        NaN
# 607                  NaN  ...                        NaN
# 608                  4.0  ...                        NaN
# 609                  4.0  ...                        NaN
# 610                  NaN  ...                        NaN
#
# title   anohana: The Flower We Saw That Day - The Movie (2013)  \
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# ...                                                   ...
# 606                                                   NaN
# 607                                                   NaN
# 608                                                   NaN
# 609                                                   NaN
# 610                                                   NaN
#
# title   Silver Spoon (2014)  Love Live! The School Idol Movie (2015)  \
# userId
# 1                       NaN                                      NaN
# 2                       NaN                                      NaN
# 3                       NaN                                      NaN
# 4                       NaN                                      NaN
# 5                       NaN                                      NaN
# ...                     ...                                      ...
# 606                     NaN                                      NaN
# 607                     NaN                                      NaN
# 608                     NaN                                      NaN
# 609                     NaN                                      NaN
# 610                     NaN                                      NaN
#
# title   Jon Stewart Has Left the Building (2015)  \
# userId
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# ...                                          ...
# 606                                          NaN
# 607                                          NaN
# 608                                          NaN
# 609                                          NaN
# 610                                          NaN
#
# title   Black Butler: Book of the Atlantic (2017)  \
# userId
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# ...                                           ...
# 606                                           NaN
# 607                                           NaN
# 608                                           NaN
# 609                                           NaN
# 610                                           NaN
#
# title   No Game No Life: Zero (2017)  Flint (2017)  \
# userId
# 1                                NaN           NaN
# 2                                NaN           NaN
# 3                                NaN           NaN
# 4                                NaN           NaN
# 5                                NaN           NaN
# ...                              ...           ...
# 606                              NaN           NaN
# 607                              NaN           NaN
# 608                              NaN           NaN
# 609                              NaN           NaN
# 610                              NaN           NaN
#
# title   Bungo Stray Dogs: Dead Apple (2018)  \
# userId
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# ...                                     ...
# 606                                     NaN
# 607                                     NaN
# 608                                     NaN
# 609                                     NaN
# 610                                     NaN
#
# title   Andrew Dice Clay: Dice Rules (1991)
# userId
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# ...                                     ...
# 606                                     NaN
# 607                                     NaN
# 608                                     NaN
# 609                                     NaN
# 610                                     NaN
#
# [610 rows x 9724 columns]

# %% [markdown]
# ### 2.3 calculate matrix sparsity

# %%
# calculate the sparsity
user_item.isna().sum().sum()/user_item.size
# Out:
# 0.9830003169443864

# %% [markdown]
# ### 2.3 delete all movies with less than 20 votes

# %%
# define mask with all movieIds having at least 20 votes
mask_at_least_20_evals = user_item.notna().sum() >= 20
# drop these user Ids (within the transposed dataframe (with movieId as index))
user_item = user_item.T.drop(user_item.T.loc[~mask_at_least_20_evals].index).T
user_item
# Out:
# title   Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# userId
# 1                    4.0             NaN                      4.0
# 2                    NaN             NaN                      NaN
# 3                    NaN             NaN                      NaN
# 4                    NaN             NaN                      NaN
# 5                    4.0             NaN                      NaN
# ...                  ...             ...                      ...
# 606                  2.5             NaN                      NaN
# 607                  4.0             NaN                      NaN
# 608                  2.5             2.0                      2.0
# 609                  3.0             NaN                      NaN
# 610                  5.0             NaN                      NaN
#
# title   Father of the Bride Part II (1995)  Heat (1995)  Sabrina (1995)  \
# userId
# 1                                      NaN          4.0             NaN
# 2                                      NaN          NaN             NaN
# 3                                      NaN          NaN             NaN
# 4                                      NaN          NaN             NaN
# 5                                      NaN          NaN             NaN
# ...                                    ...          ...             ...
# 606                                    NaN          NaN             2.5
# 607                                    NaN          NaN             NaN
# 608                                    NaN          NaN             NaN
# 609                                    NaN          NaN             NaN
# 610                                    NaN          5.0             NaN
#
# title   GoldenEye (1995)  American President, The (1995)  Casino (1995)  \
# userId
# 1                    NaN                             NaN            NaN
# 2                    NaN                             NaN            NaN
# 3                    NaN                             NaN            NaN
# 4                    NaN                             NaN            NaN
# 5                    NaN                             NaN            NaN
# ...                  ...                             ...            ...
# 606                  NaN                             2.5            NaN
# 607                  NaN                             3.0            NaN
# 608                  4.0                             NaN            4.5
# 609                  4.0                             NaN            NaN
# 610                  NaN                             NaN            4.5
#
# title   Sense and Sensibility (1995)  ...  Captain America: Civil War (2016)  \
# userId                                ...
# 1                                NaN  ...                                NaN
# 2                                NaN  ...                                NaN
# 3                                NaN  ...                                NaN
# 4                                NaN  ...                                NaN
# 5                                NaN  ...                                NaN
# ...                              ...  ...                                ...
# 606                              4.0  ...                                NaN
# 607                              NaN  ...                                NaN
# 608                              NaN  ...                                NaN
# 609                              NaN  ...                                NaN
# 610                              NaN  ...                                5.0
#
# title   Doctor Strange (2016)  The Martian (2015)  Inside Out (2015)  \
# userId
# 1                         NaN                 NaN                NaN
# 2                         NaN                 NaN                NaN
# 3                         NaN                 NaN                NaN
# 4                         NaN                 NaN                NaN
# 5                         NaN                 NaN                NaN
# ...                       ...                 ...                ...
# 606                       NaN                 NaN                NaN
# 607                       NaN                 NaN                NaN
# 608                       NaN                 NaN                NaN
# 609                       NaN                 NaN                NaN
# 610                       3.5                 3.5                3.5
#
# title   The Revenant (2015)  Big Short, The (2015)  Zootopia (2016)  \
# userId
# 1                       NaN                    NaN              NaN
# 2                       NaN                    NaN              NaN
# 3                       NaN                    NaN              NaN
# 4                       NaN                    NaN              NaN
# 5                       NaN                    NaN              NaN
# ...                     ...                    ...              ...
# 606                     NaN                    NaN              NaN
# 607                     NaN                    NaN              NaN
# 608                     NaN                    NaN              NaN
# 609                     NaN                    NaN              NaN
# 610                     4.5                    4.0              4.0
#
# title   Arrival (2016)  Rogue One: A Star Wars Story (2016)  Logan (2017)
# userId
# 1                  NaN                                  NaN           NaN
# 2                  NaN                                  NaN           NaN
# 3                  NaN                                  NaN           NaN
# 4                  NaN                                  NaN           NaN
# 5                  NaN                                  NaN           NaN
# ...                ...                                  ...           ...
# 606                NaN                                  NaN           NaN
# 607                NaN                                  NaN           NaN
# 608                NaN                                  NaN           NaN
# 609                NaN                                  NaN           NaN
# 610                5.0                                  4.0           5.0
#
# [610 rows x 1295 columns]

# %% [markdown]
# ### 2.4 Fill the NaN by average of movie

# %%
user_item_f = user_item.fillna(user_item.mean())
user_item_f
# Out:
# title   Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# userId
# 1                4.00000        3.431818                 4.000000
# 2                3.92093        3.431818                 3.259615
# 3                3.92093        3.431818                 3.259615
# 4                3.92093        3.431818                 3.259615
# 5                4.00000        3.431818                 3.259615
# ...                  ...             ...                      ...
# 606              2.50000        3.431818                 3.259615
# 607              4.00000        3.431818                 3.259615
# 608              2.50000        2.000000                 2.000000
# 609              3.00000        3.431818                 3.259615
# 610              5.00000        3.431818                 3.259615
#
# title   Father of the Bride Part II (1995)  Heat (1995)  Sabrina (1995)  \
# userId
# 1                                 3.071429     4.000000        3.185185
# 2                                 3.071429     3.946078        3.185185
# 3                                 3.071429     3.946078        3.185185
# 4                                 3.071429     3.946078        3.185185
# 5                                 3.071429     3.946078        3.185185
# ...                                    ...          ...             ...
# 606                               3.071429     3.946078        2.500000
# 607                               3.071429     3.946078        3.185185
# 608                               3.071429     3.946078        3.185185
# 609                               3.071429     3.946078        3.185185
# 610                               3.071429     5.000000        3.185185
#
# title   GoldenEye (1995)  American President, The (1995)  Casino (1995)  \
# userId
# 1               3.496212                        3.671429       3.926829
# 2               3.496212                        3.671429       3.926829
# 3               3.496212                        3.671429       3.926829
# 4               3.496212                        3.671429       3.926829
# 5               3.496212                        3.671429       3.926829
# ...                  ...                             ...            ...
# 606             3.496212                        2.500000       3.926829
# 607             3.496212                        3.000000       3.926829
# 608             4.000000                        3.671429       4.500000
# 609             4.000000                        3.671429       3.926829
# 610             3.496212                        3.671429       4.500000
#
# title   Sense and Sensibility (1995)  ...  Captain America: Civil War (2016)  \
# userId                                ...
# 1                           3.776119  ...                           3.613636
# 2                           3.776119  ...                           3.613636
# 3                           3.776119  ...                           3.613636
# 4                           3.776119  ...                           3.613636
# 5                           3.776119  ...                           3.613636
# ...                              ...  ...                                ...
# 606                         4.000000  ...                           3.613636
# 607                         3.776119  ...                           3.613636
# 608                         3.776119  ...                           3.613636
# 609                         3.776119  ...                           3.613636
# 610                         3.776119  ...                           5.000000
#
# title   Doctor Strange (2016)  The Martian (2015)  Inside Out (2015)  \
# userId
# 1                    3.704545                 4.0           3.813953
# 2                    3.704545                 4.0           3.813953
# 3                    3.704545                 4.0           3.813953
# 4                    3.704545                 4.0           3.813953
# 5                    3.704545                 4.0           3.813953
# ...                       ...                 ...                ...
# 606                  3.704545                 4.0           3.813953
# 607                  3.704545                 4.0           3.813953
# 608                  3.704545                 4.0           3.813953
# 609                  3.704545                 4.0           3.813953
# 610                  3.500000                 3.5           3.500000
#
# title   The Revenant (2015)  Big Short, The (2015)  Zootopia (2016)  \
# userId
# 1                  3.903226               3.961538         3.890625
# 2                  3.903226               3.961538         3.890625
# 3                  3.903226               3.961538         3.890625
# 4                  3.903226               3.961538         3.890625
# 5                  3.903226               3.961538         3.890625
# ...                     ...                    ...              ...
# 606                3.903226               3.961538         3.890625
# 607                3.903226               3.961538         3.890625
# 608                3.903226               3.961538         3.890625
# 609                3.903226               3.961538         3.890625
# 610                4.500000               4.000000         4.000000
#
# title   Arrival (2016)  Rogue One: A Star Wars Story (2016)  Logan (2017)
# userId
# 1             3.980769                             3.925926          4.28
# 2             3.980769                             3.925926          4.28
# 3             3.980769                             3.925926          4.28
# 4             3.980769                             3.925926          4.28
# 5             3.980769                             3.925926          4.28
# ...                ...                                  ...           ...
# 606           3.980769                             3.925926          4.28
# 607           3.980769                             3.925926          4.28
# 608           3.980769                             3.925926          4.28
# 609           3.980769                             3.925926          4.28
# 610           5.000000                             4.000000          5.00
#
# [610 rows x 1295 columns]

# %% [markdown]
# ## 3. create a User-User-Matrix with Cosine-Simularity

# %% [markdown]
# ### 3.1. create user-user-matrix manually

# %%
def cosine_sim(vec_x, vec_y):
    '''calculate the cosine similarity of vector x and vector y'''
    assert len(vec_x) == len(vec_y)
    num = np.dot(vec_x, vec_y)
    # dot product of a vector with itself = the sum of all squared vector-elements 
    denom = np.sqrt(np.dot(vec_x, vec_x)) * np.sqrt(np.dot(vec_y, vec_y))
    return num/denom

# %%
def create_user_user_matrix(df):
    '''creates a user-user-matrix of cosine similarities'''
    users = df.index
    cos_sim_list = [[cosine_sim(df.loc[user_a], df.loc[user_b]) for user_a in users] for user_b in users]
    user_user_matrix = pd.DataFrame(data=cos_sim_list, columns=users, index=users)
    return user_user_matrix

# %%
# Create the user-user-matrix manually
user_user_cos = create_user_user_matrix(user_item_f)
user_user_cos
# Out:
# userId       1         2         3         4         5         6         7    \
# userId
# 1       1.000000  0.994206  0.989798  0.987675  0.993643  0.990087  0.989413
# 2       0.994206  1.000000  0.994932  0.992378  0.998747  0.995278  0.994542
# 3       0.989798  0.994932  1.000000  0.987847  0.994074  0.991245  0.990120
# 4       0.987675  0.992378  0.987847  1.000000  0.991389  0.988909  0.988778
# 5       0.993643  0.998747  0.994074  0.991389  1.000000  0.994638  0.993855
# ...          ...       ...       ...       ...       ...       ...       ...
# 606     0.988512  0.994172  0.989013  0.986998  0.993459  0.989494  0.988986
# 607     0.990445  0.995410  0.991144  0.988850  0.994785  0.992167  0.991132
# 608     0.977803  0.984143  0.979801  0.976331  0.983225  0.978175  0.978339
# 609     0.994362  0.999473  0.995051  0.992621  0.998893  0.995375  0.994607
# 610     0.988388  0.993805  0.989796  0.986249  0.992800  0.989335  0.988436
#
# userId       8         9         10   ...       601       602       603  \
# userId                                ...
# 1       0.993621  0.994149  0.989263  ...  0.993340  0.991866  0.976639
# 2       0.998526  0.999149  0.994342  ...  0.998478  0.996876  0.983352
# 3       0.994039  0.994803  0.989916  ...  0.993958  0.992439  0.979459
# 4       0.991908  0.992265  0.989138  ...  0.991237  0.990616  0.976278
# 5       0.997625  0.998476  0.993514  ...  0.997882  0.996065  0.982864
# ...          ...       ...       ...  ...       ...       ...       ...
# 606     0.993359  0.993918  0.988491  ...  0.993485  0.991477  0.978825
# 607     0.994709  0.995244  0.990582  ...  0.994994  0.993229  0.979893
# 608     0.983644  0.983880  0.977983  ...  0.983896  0.981886  0.968146
# 609     0.998788  0.999291  0.994515  ...  0.998710  0.996893  0.983689
# 610     0.992909  0.993686  0.988008  ...  0.993190  0.991314  0.978013
#
# userId       604       605       606       607       608       609       610
# userId
# 1       0.992999  0.991463  0.988512  0.990445  0.977803  0.994362  0.988388
# 2       0.998277  0.997103  0.994172  0.995410  0.984143  0.999473  0.993805
# 3       0.993931  0.992715  0.989013  0.991144  0.979801  0.995051  0.989796
# 4       0.991404  0.990710  0.986998  0.988850  0.976331  0.992621  0.986249
# 5       0.997518  0.996203  0.993459  0.994785  0.983225  0.998893  0.992800
# ...          ...       ...       ...       ...       ...       ...       ...
# 606     0.993333  0.991823  1.000000  0.989557  0.979159  0.994398  0.987909
# 607     0.994334  0.993123  0.989557  1.000000  0.980376  0.995461  0.989609
# 608     0.982829  0.981889  0.979159  0.980376  1.000000  0.984611  0.978510
# 609     0.998551  0.997338  0.994398  0.995461  0.984611  1.000000  0.993551
# 610     0.992345  0.991400  0.987909  0.989609  0.978510  0.993551  1.000000
#
# [610 rows x 610 columns]

# %% [markdown]
# ### 3.2. create user-user-matrix with scikit learn

# %%
user_user_sklearn = cosine_similarity(user_item_f)
user_user_sklearn = pd.DataFrame(data=user_user_sklearn, columns=user_item_f.index, index=user_item_f.index)
user_user_sklearn
# Out:
# userId       1         2         3         4         5         6         7    \
# userId
# 1       1.000000  0.994206  0.989798  0.987675  0.993643  0.990087  0.989413
# 2       0.994206  1.000000  0.994932  0.992378  0.998747  0.995278  0.994542
# 3       0.989798  0.994932  1.000000  0.987847  0.994074  0.991245  0.990120
# 4       0.987675  0.992378  0.987847  1.000000  0.991389  0.988909  0.988778
# 5       0.993643  0.998747  0.994074  0.991389  1.000000  0.994638  0.993855
# ...          ...       ...       ...       ...       ...       ...       ...
# 606     0.988512  0.994172  0.989013  0.986998  0.993459  0.989494  0.988986
# 607     0.990445  0.995410  0.991144  0.988850  0.994785  0.992167  0.991132
# 608     0.977803  0.984143  0.979801  0.976331  0.983225  0.978175  0.978339
# 609     0.994362  0.999473  0.995051  0.992621  0.998893  0.995375  0.994607
# 610     0.988388  0.993805  0.989796  0.986249  0.992800  0.989335  0.988436
#
# userId       8         9         10   ...       601       602       603  \
# userId                                ...
# 1       0.993621  0.994149  0.989263  ...  0.993340  0.991866  0.976639
# 2       0.998526  0.999149  0.994342  ...  0.998478  0.996876  0.983352
# 3       0.994039  0.994803  0.989916  ...  0.993958  0.992439  0.979459
# 4       0.991908  0.992265  0.989138  ...  0.991237  0.990616  0.976278
# 5       0.997625  0.998476  0.993514  ...  0.997882  0.996065  0.982864
# ...          ...       ...       ...  ...       ...       ...       ...
# 606     0.993359  0.993918  0.988491  ...  0.993485  0.991477  0.978825
# 607     0.994709  0.995244  0.990582  ...  0.994994  0.993229  0.979893
# 608     0.983644  0.983880  0.977983  ...  0.983896  0.981886  0.968146
# 609     0.998788  0.999291  0.994515  ...  0.998710  0.996893  0.983689
# 610     0.992909  0.993686  0.988008  ...  0.993190  0.991314  0.978013
#
# userId       604       605       606       607       608       609       610
# userId
# 1       0.992999  0.991463  0.988512  0.990445  0.977803  0.994362  0.988388
# 2       0.998277  0.997103  0.994172  0.995410  0.984143  0.999473  0.993805
# 3       0.993931  0.992715  0.989013  0.991144  0.979801  0.995051  0.989796
# 4       0.991404  0.990710  0.986998  0.988850  0.976331  0.992621  0.986249
# 5       0.997518  0.996203  0.993459  0.994785  0.983225  0.998893  0.992800
# ...          ...       ...       ...       ...       ...       ...       ...
# 606     0.993333  0.991823  1.000000  0.989557  0.979159  0.994398  0.987909
# 607     0.994334  0.993123  0.989557  1.000000  0.980376  0.995461  0.989609
# 608     0.982829  0.981889  0.979159  0.980376  1.000000  0.984611  0.978510
# 609     0.998551  0.997338  0.994398  0.995461  0.984611  1.000000  0.993551
# 610     0.992345  0.991400  0.987909  0.989609  0.978510  0.993551  1.000000
#
# [610 rows x 610 columns]

# %% [markdown]
# ## 4. Recommend movies to users

# %% [markdown]
# ### 4.1. create a dict of unseen movies

# %%
# melt the dataframe to long_format
init_long = pd.melt(user_item.reset_index(),id_vars='userId',value_name='ratings',var_name='movieId')
# Create a dict with a list of unseen movies (value) for each user (key)
unseen_dict = {user : list(init_long['movieId'].loc[(init_long['userId'] == user) & (init_long['ratings'].isna())]) 
                   for user in user_item.index}
# unseen_dict

# %% [markdown]
# ### 4.2. create a dictionary of most similar users

# %%
# Create a dict with a descending list of similar users by cosine similarity) (value) for each user (key)
top_us_dict = {user : 
    list(user_user_cos[user].loc[user_user_cos.index != user].sort_values(ascending=False).index) 
    for user in user_user_cos.index}
# top_us_dict

# %% [markdown]
# ### 4. 3. Recommender based on top 5 users

# %%
def recommend_movie(user):
    recommendations = []
    # iterate over all movies the user hasn't seen and calculate it's score with cosine similarity
    for movie in unseen_dict[user]:
        # get a set of all users who have seen the movie
        user_rated_tot = set(user_item.loc[~user_item[movie].isna()].index)
        # take only those users who are in the top 5
        top_5_seen = []
        count = 0
        for top_user in top_us_dict[user]:
            if count == 5:
                break
            if top_user in user_rated_tot:
                top_5_seen.append(top_user)
                count += 1
        num = 0
        den = 0
        #calculate the score for the movie
        for neighbor in top_5_seen:
            sim = user_user_cos[user][neighbor]
            rating = user_item[movie][neighbor]
            num += sim * rating
            den += sim + 0.0000001
        # append each movie to the recommendations list
        recommendations.append([movie, num / den])
    # create a dataframe out of the recommendations and sort it by score
    result = pd.DataFrame(data=recommendations, columns=['movie', 'score'])
    result.sort_values(by='score', ascending=False, inplace=True)
    result.set_index(['movie'], inplace=True)

    return result

# %%
recommendations = recommend_movie(1)
recommendations
# Out:
#                                                    score
# movie
# Cinema Paradiso (Nuovo cinema Paradiso) (1989)  4.900014
# Life Is Beautiful (La Vita è bella) (1997)      4.899987
# To Kill a Mockingbird (1962)                    4.799993
# Third Man, The (1949)                           4.799980
# Brazil (1985)                                   4.700034
# ...                                                  ...
# Coneheads (1993)                                1.799988
# RoboCop 2 (1990)                                1.700618
# Babe: Pig in the City (1998)                    1.700160
# Mask of Zorro, The (1998)                       1.600232
# Godzilla (1998)                                 1.599871
#
# [1114 rows x 1 columns]
