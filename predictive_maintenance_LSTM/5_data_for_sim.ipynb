# %%
import pandas as pd
import numpy as np
import os.path
import pickle
from tensorflow import keras
from keras.models import Sequential, load_model
from csv import reader
import tensorflow_addons as tfa

from sklearn.preprocessing import MinMaxScaler

# %%
# defining the parameters of the data (MUST FIT TO THE MODEL ELSE PREDICTION FAILURE)
REGRESSION = False
SEQUENCE_LENGTH = 50 
Y_THRESHOLD = 70 
FILENAME_IDS = './simulation_data/ids.txt'

if REGRESSION:
    FILENAME = './simulation_data/data_regr.npy'
    model_reg = load_model('./models/reg_model.h5')
    DAYS_MEAN = 6 
    DAYS_VAR = 12 
else:
    FILENAME = './simulation_data/data_class.npy'
    model_class = load_model('./models/class_model.h5')
    # model_class = pickle.load(open('./models/class_model.sav', 'rb'))
    DAYS_MEAN = 6 
    DAYS_VAR = 12

# %%
def add_mean_var(df, days_mean=5, days_var=5):
    # create a df with the mean of the parameter-days with the same index as the original df
    no_days_mean = days_mean
    names = ['mean_' + feature for feature in FEATURES]
    df_mean = df.groupby('id')[FEATURES].rolling(no_days_mean).mean()
    df_mean.columns = names
    df_mean.reset_index(inplace=True)
    df_mean.drop(columns=['level_1', 'id'], inplace=True)
    
    # create a df with the var of the parameter-days with the same index as the original df
    no_days_var = days_var
    names = ['var_' + feature for feature in FEATURES]
    df_var = df.groupby('id')[FEATURES].rolling(no_days_var).var()
    df_var.columns = names
    df_var.reset_index(inplace=True)
    df_var.drop(columns=['level_1', 'id'], inplace=True)
    return df_mean, df_var

# %%
def create_sequences(df_eng, seq_len, features, labels):
    X_samples = []
    y_samples = []
    for i in range(df_eng.shape[0]):
        if i + seq_len - 1 >= df_eng.shape[0]:
            break
        X_samples.append(df_eng[features].iloc[i : i + seq_len]) # appending a list of all feature elements to the list
        y_samples.extend(df_eng[labels[0]].iloc[i + seq_len - 1]) # just add the y-value to a list (1D) - appending would create 2D
    print(df_eng['id'].unique(), np.array(X_samples).shape, np.array(y_samples).shape)
    return np.array(X_samples), np.array(y_samples)

# %%
# Load data
df_train = pd.read_csv('./reworked_data/train_cat_set1.csv', header=0)
df_test = pd.read_csv('./reworked_data/test_cat_set1.csv', header=0)
df_train.drop(columns=['Unnamed: 0'], inplace=True)
df_test.drop(columns=['Unnamed: 0'], inplace=True)
print(df_test.shape)
# Out:
# (29692, 19)

# %%
# copy the original RUL data to display it on scree
df_train['rul_orig'] = df_train['rul']
df_test['rul_orig'] = df_test['rul']

# %%
#change the relu to 100 if not within the last 60 days
# change rul to 100 for everything bigger. not important to predict that right. Only the last 100 days are relevant
df_train['rul'].loc[df_train['rul'] > Y_THRESHOLD] = Y_THRESHOLD
df_test['rul'].loc[df_test['rul'] > Y_THRESHOLD] = Y_THRESHOLD
# Out:
# /tmp/ipykernel_7180/2574588552.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['rul'].loc[df_train['rul'] > Y_THRESHOLD] = Y_THRESHOLD
# /tmp/ipykernel_7180/2574588552.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['rul'].loc[df_test['rul'] > Y_THRESHOLD] = Y_THRESHOLD

# %%
# create min max scaler for features
INFO = ['id', 'cycle', 'rul', 'label', 'rul_orig']
FEATURES = df_train.drop(columns=INFO).columns
scaler = MinMaxScaler()
df_feat = pd.DataFrame(data=scaler.fit_transform(df_train[FEATURES]), columns=scaler.get_feature_names_out(), index=df_train.index)
df_train = pd.merge(left=df_train[INFO], right=df_feat, left_index=True, right_index=True)
df_feat_test = pd.DataFrame(data=scaler.transform(df_test[FEATURES]), columns=scaler.get_feature_names_out(), index=df_test.index)
df_test = pd.merge(left=df_test[INFO], right=df_feat_test, left_index=True, right_index=True)

# %%
# add rolling variance and mean
df_train_mean, df_train_var = add_mean_var(df_train, DAYS_MEAN, DAYS_VAR)
df_test_mean, df_test_var = add_mean_var(df_test, DAYS_MEAN, DAYS_VAR)
print(df_test_mean.shape)
# Out:
# (29692, 15)

# %%
# concattenate the dataframes
df_train = df_train.merge(df_train_mean, left_index=True, right_index=True)
df_train = df_train.merge(df_train_var, left_index=True, right_index=True)
df_test = df_test.merge(df_test_mean, left_index=True, right_index=True)
df_test = df_test.merge(df_test_var, left_index=True, right_index=True)

# drop the na which have occured due to the rolling mean/var
df_train.dropna(inplace=True)
df_test.dropna(inplace=True)
print(df_test.shape)
# Out:
# (27492, 50)

# %%
# creates a dicionary with key: id value: list of x_test arrays and y_test rul and label for the simulation
LABELS = [['rul_orig']]
FEATURES_NEW = df_train.drop(columns=INFO).columns
arrays = dict()
id_list = df_test['id'].unique()
# save all ids of the data in a txt to be used in the selector of the page
file_ids = open(FILENAME_IDS,'w')
# iterate over the ids. When timeseries is at least 1 Sequence create and add x and y sequences
check_list = []
for id in id_list:
    df = df_test.loc[df_test['id'] == id]
    if df.shape[0] >= SEQUENCE_LENGTH:
        X_test, y_test = create_sequences(df, SEQUENCE_LENGTH, FEATURES_NEW, LABELS)
        arrays[str(id) + '-x'] = X_test
        arrays[str(id) + '-y_rul_orig'] = y_test
        if REGRESSION:
            arrays[str(id) + '-y_regr_pred'] = np.array(model_reg.predict(X_test))
        else:
            arrays[str(id) + '-y_class_pred'] = np.array(model_class.predict(X_test))
        file_ids.write(f"{id} - {y_test[0]} - {y_test[-1]},")
        check_list.append(id)
np.save(FILENAME, arrays)
file_ids.close()
# Out:
# [1003] (66, 50, 45) (66,)
# 3/3 [==============================] - 1s 14ms/step
# [1004] (46, 50, 45) (46,)
# 2/2 [==============================] - 0s 11ms/step
# [1005] (38, 50, 45) (38,)
# 2/2 [==============================] - 0s 11ms/step
# [1006] (45, 50, 45) (45,)
# 2/2 [==============================] - 0s 13ms/step
# [1007] (100, 50, 45) (100,)
# 4/4 [==============================] - 0s 11ms/step
# [1008] (106, 50, 45) (106,)
# 4/4 [==============================] - 0s 12ms/step
# [1010] (132, 50, 45) (132,)
# 5/5 [==============================] - 0s 12ms/step
# [1011] (23, 50, 45) (23,)
# 1/1 [==============================] - 0s 28ms/step
# [1012] (157, 50, 45) (157,)
# 5/5 [==============================] - 0s 12ms/step
# [1013] (135, 50, 45) (135,)
# 5/5 [==============================] - 0s 21ms/step
# [1015] (16, 50, 45) (16,)
# 1/1 [==============================] - 0s 29ms/step
# [1016] (53, 50, 45) (53,)
# 2/2 [==============================] - 0s 12ms/step
# [1017] (105, 50, 45) (105,)
# 4/4 [==============================] - 0s 10ms/step
# [1018] (73, 50, 45) (73,)
# 3/3 [==============================] - 0s
# 5/5 [==============================] - 0s 12ms/step
# [3096] (298, 50, 45) (298,)
# 10/10 [==============================] - 0s 11ms/step
# [3097] (35, 50, 45) (35,)
# 2/2 [==============================] - 0s 8ms/step
# [3098] (122, 50, 45) (122,)
# 4/4 [==============================] - 0s 11ms/step
# [3099] (229, 50, 45) (229,)
# 8/8 [==============================] - 0s 11ms/step
# [3100] (187, 50, 45) (187,)
# 6/6 [==============================] - 0s 10ms/step

# %%
# array: 
# axis 0: contains all sequences of an ID: from 0 to shape[0] -1 
# axis 1: are all datasets in one sequence --> [-1] is the last data-row of the sequence (leading to the end of all series)
# axis 2: are all datapoints in the dataset --> first 15 are the sensors to display
# print(arrays['1002-x'][0][-1][:15])
# print(arrays['1002-x'].shape[0])
print(arrays['1003-x'].shape)
# Out:
# (66, 50, 45)

# %%
# create a dataframe out of it
df = pd.DataFrame(arrays['1003-x'][1])
SHOW_FEATURES = 12
FEATURES_PLOTS = [i for i in range(SHOW_FEATURES, df.shape[1])]
df_plot = df.drop(columns=FEATURES_PLOTS)
df_plot[-20:]
if REGRESSION:
    print(arrays['1004-x'].shape, arrays['1004-y_regr_pred'].shape, arrays['1004-y_rul_orig'].shape)
else:
    print(arrays['1004-x'].shape, arrays['1004-y_class_pred'].shape, arrays['1004-y_rul_orig'].shape)
# Out:
# (46, 50, 45) (46, 3) (46,)

# %%
if REGRESSION:
    # Check the predictions and get indication which engines to use for presentation
    SE = 0
    N = 0
    SE60 = 0
    N60 = 0
    SE30 = 0
    N30 = 0
    SE15 = 0
    N15 = 0
    for id in check_list:
        SE60 = 0
        N60 = 0
        SE30 = 0
        N30 = 0
        SE15 = 0
        N15 = 0
        for y_pred, y_true in zip(arrays[str(id) + '-y_regr_pred'], arrays[str(id) + '-y_rul_orig']):
            # y_pred_round = round({y_pred[0]},2)
            # delta = y_true - round({y_pred[0]},2)
            if y_true >= 70:
                y_true = 70
            if 30 < y_true <=60:
                SE60 += np.square(y_true - y_pred[0])    
                N60 += 1
            if 15 < y_true <=30:
                SE30 += np.square(y_true - y_pred[0])    
                N30 += 1
            if -1 < y_true <=15:
                SE15 += np.square(y_true - y_pred[0])    
                N15 += 1
                
                #print(f"ID: {id} y_true: {y_true} y_pred: round({y_pred[0]},2), delta = ")
            SE += np.square(y_true - y_pred[0])
            N += 1
        if N60 > 0: 
            MSE60 = SE60 / N60
            RMSE60 = np.sqrt(MSE60)
        else: 
            MSE60 = None
            RMSE60 = None
        if N30 > 0: 
            MSE30 = SE30 / N30
            RMSE30 = np.sqrt(MSE30)
        else: 
            MSE30 = None
            RMSE30 = None
        if N15 > 0: 
            MSE15 = SE15 / N15
            RMSE15 = np.sqrt(MSE15)
        else: 
            MSE15 = None
            RMSE15 = None
        print(f"ID:, {id}, RMSE60:, {RMSE60}, RMSE30:, {RMSE30}, RMSE15:, {RMSE15},")
    MSE = SE / N
    RMSE = np.sqrt(MSE)
    print(f"RMSE: {RMSE} MSE: {MSE}")
else:
    # Check the predictions and get indication which engines to use for presentation
    for id in check_list:
        CLASS60 = 0
        N60 = 0
        CLASS30 = 0
        N30 = 0
        CLASS15 = 0
        N15 = 0
        for y_pred, y_true in zip(arrays[str(id) + '-y_class_pred'], arrays[str(id) + '-y_rul_orig']):
            y_pred = np.argmax(y_pred)
            if 30 < y_true <=60:
                if y_pred == 0:
                    CLASS60 += 1
                N60 += 1
            if 15 < y_true <=30:
                if y_pred == 1:
                    CLASS30 += 1
                N30 += 1
            if -1 < y_true <=15:
                if y_pred == 2:
                    CLASS15 += 1
                N15 += 1
                #print(f"ID: {id} y_true: {y_true} y_pred: round({y_pred[0]},2), delta = ")
        if N60 > 0: 
            ACC60 = CLASS60 / N60
        else: 
            ACC60 = None
        if N30 > 0: 
            ACC30 = CLASS30 / N30
        else: 
            ACC30 = None
        if N15 > 0: 
            ACC15 = CLASS15 / N15
        else: 
            ACC15 = None
        print(f"ID:, {id}, ACC60:, {ACC60}, ACC30:, {ACC30}, ACC15:, {ACC15},")
# Out:
# ID:, 1003, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1004, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1005, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1006, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1007, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1008, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1010, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1011, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1012, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1013, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1015, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1016, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1017, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 1018, ACC60:, 1.0, ACC30:, 0.6666666666666666, ACC15:, None,
# ID:, 1019, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1020, ACC60:, 1.0, ACC30:, 0.8666666666666667, ACC15:, None,
# ID:, 1021, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 1023, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1024, ACC60:, 1.0, ACC30:, 1.0, ACC15:, None,
# ID:, 1026, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1027, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1028, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1029, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1030, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1031, ACC60:, 1.0, ACC30:, 0.6666666666666666, ACC15:, 1.0,
# ID:, 1032, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 1034, ACC60:, 1.0, ACC30:, 0.7333333333333333, ACC15:, 1.0,
# ID:, 1035, ACC60:, 0.9, ACC30:, 1.0, ACC15:, 0.4,
# ID:, 1036, ACC60:, 1.0, ACC30:, 0.4166666666666667, ACC15:, None,
# ID:, 1037, ACC60:, 1.0, ACC30:, 0.4, ACC15:, None,
# ID:, 1038, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 1040, ACC60:, 0.9, ACC30:, 1.0, ACC15:, None,
# ID:, 1041, ACC60:, 1.0, ACC30:, 0.46153846153846156, ACC15:, None,
# ID:, 1042, ACC60:, 1.0, ACC30:, 0.8, ACC15:, 0.6666666666666666,
# ID:, 1043, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 1045, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1046, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 1047, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1048, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1049, ACC60:, 1.0, ACC30:, 0.9, ACC15:, None,
# ID:, 1050, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1051, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1052, ACC60:, 1.0, ACC30:, 0.0, ACC15:, None,
# ID:, 1053, ACC60:, 1.0, ACC30:, 0.0, ACC15:, None,
# ID:, 1054, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1055, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1056, ACC60:, 1.0, ACC30:, 0.8666666666666667, ACC15:, 1.0,
# ID:, 1057, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1058, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 1059, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1060, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1061, ACC60:, 1.0, ACC30:, 1.0, ACC15:, None,
# ID:, 1062, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 1063, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1064, ACC60:, 0.9666666666666667, ACC30:, 1.0, ACC15:, None,
# ID:, 1065, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1066, ACC60:, 1.0, ACC30:, 0.4666666666666667, ACC15:, 0.0,
# ID:, 1067, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1068, ACC60:, 1.0, ACC30:, 0.7333333333333333, ACC15:, 1.0,
# ID:, 1070, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1071, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1072, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 1073, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1074, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1075, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1076, ACC60:, 0.8, ACC30:, 0.9333333333333333, ACC15:, 1.0,
# ID:, 1077, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 1078, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1079, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1080, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1081, ACC60:, 0.8, ACC30:, 0.9333333333333333, ACC15:, 0.75,
# ID:, 1082, ACC60:, 1.0, ACC30:, 0.4666666666666667, ACC15:, 0.5714285714285714,
# ID:, 1083, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1084, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 1086, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1088, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1089, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1090, ACC60:, 0.9666666666666667, ACC30:, 1.0, ACC15:, None,
# ID:, 1091, ACC60:, 0.8695652173913043, ACC30:, None, ACC15:, None,
# ID:, 1092, ACC60:, 0.9333333333333333, ACC30:, 1.0, ACC15:, None,
# ID:, 1093, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1094, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 1095, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1096, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1097, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1098, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 1099, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 1100, ACC60:, 0.9, ACC30:, 1.0, ACC15:, None,
# ID:, 3001, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3002, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3003, ACC60:, 1.0, ACC30:, 0.0, ACC15:, None,
# ID:, 3004, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3005, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3006, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3007, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3008, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3009, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3010, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3011, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3012, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3013, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3014, ACC60:, 0.8666666666666667, ACC30:, None, ACC15:, None,
# ID:, 3015, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3016, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3017, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3018, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3019, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3020, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3021, ACC60:, 0.9, ACC30:, 1.0, ACC15:, None,
# ID:, 3022, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3023, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3024, ACC60:, 1.0, ACC30:, 0.6666666666666666, ACC15:, 0.0,
# ID:, 3025, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3026, ACC60:, 1.0, ACC30:, 1.0, ACC15:, 0.4,
# ID:, 3027, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3028, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3029, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3030, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3031, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3032, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3033, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3034, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3035, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3036, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3038, ACC60:, 1.0, ACC30:, 0.8888888888888888, ACC15:, None,
# ID:, 3039, ACC60:, 1.0, ACC30:, 0.8666666666666667, ACC15:, 0.5,
# ID:, 3040, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3041, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3042, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3043, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3044, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3045, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3046, ACC60:, 1.0, ACC30:, 0.8666666666666667, ACC15:, 0.6666666666666666,
# ID:, 3048, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3049, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3050, ACC60:, 1.0, ACC30:, 0.8, ACC15:, 0.0,
# ID:, 3051, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3053, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3055, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3056, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3057, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3058, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3059, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3060, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3061, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3062, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3063, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3064, ACC60:, 1.0, ACC30:, 0.6666666666666666, ACC15:, None,
# ID:, 3065, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3066, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3067, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3068, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3069, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3070, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3071, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3072, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3073, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3074, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3075, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3076, ACC60:, 0.9333333333333333, ACC30:, 1.0, ACC15:, None,
# ID:, 3077, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3078, ACC60:, 0.9333333333333333, ACC30:, 1.0, ACC15:, None,
# ID:, 3079, ACC60:, 1.0, ACC30:, 0.5384615384615384, ACC15:, None,
# ID:, 3080, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3081, ACC60:, 1.0, ACC30:, 0.8, ACC15:, 0.0,
# ID:, 3082, ACC60:, 0.9, ACC30:, 1.0, ACC15:, 0.6,
# ID:, 3083, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3084, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3085, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3086, ACC60:, 1.0, ACC30:, 0.5, ACC15:, None,
# ID:, 3087, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3089, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3090, ACC60:, 1.0, ACC30:, None, ACC15:, None,
# ID:, 3092, ACC60:, 1.0, ACC30:, 0.9333333333333333, ACC15:, 0.0,
# ID:, 3093, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3094, ACC60:, 1.0, ACC30:, 0.8, ACC15:, 0.0,
# ID:, 3095, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3096, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3097, ACC60:, None, ACC30:, None, ACC15:, None,
# ID:, 3098, ACC60:, 1.0, ACC30:, 0.7142857142857143, ACC15:, None,
# ID:, 3099, ACC60:, 1.0, ACC30:, 1.0, ACC15:, 0.0,
# ID:, 3100, ACC60:, 0.9, ACC30:, 1.0, ACC15:, None,

# %%
file_id = './simulation_data/ids.txt'
with open(file_id, mode='r') as file:
    csv_read = reader(file, delimiter=',')
    id_list = [row[:-1] for row in csv_read][0]
id_list[1][:4]
# Out:
# '1004'

# %%
print(arrays['1004-y_rul_orig'][0]//10)
# Out:
# 12
