# %%
import numpy as np
from sklearn.decomposition import NMF 
import pandas as pd
import pickle

# %% [markdown]
# ## 1. Load small MovieLens-dataset

# %%
user_rating_init = pd.read_csv("./data/ml-latest-small/ratings.csv",index_col=1,)
user_rating_init.reset_index(inplace=True)
user_rating_init.drop(['timestamp'], axis=1 , inplace=True)
user_rating_init
# Out:
#         movieId  userId  rating
# 0             1       1     4.0
# 1             3       1     4.0
# 2             6       1     4.0
# 3            47       1     5.0
# 4            50       1     5.0
# ...         ...     ...     ...
# 100831   166534     610     4.0
# 100832   168248     610     5.0
# 100833   168250     610     5.0
# 100834   168252     610     5.0
# 100835   170875     610     3.0
#
# [100836 rows x 3 columns]

# %% [markdown]
# ## 2. Edit data

# %% [markdown]
# ### 2.1 Add movie titles

# %%
# pivot the table
user_item_init = pd.pivot(data=user_rating_init,
                index='userId',
                columns='movieId',
                values='rating')
user_item_init
# Out:
# movieId  1       2       3       4       5       6       7       8       \
# userId
# 1           4.0     NaN     4.0     NaN     NaN     4.0     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5           4.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 606         2.5     NaN     NaN     NaN     NaN     NaN     2.5     NaN
# 607         4.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 608         2.5     2.0     2.0     NaN     NaN     NaN     NaN     NaN
# 609         3.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 610         5.0     NaN     NaN     NaN     NaN     5.0     NaN     NaN
#
# movieId  9       10      ...  193565  193567  193571  193573  193579  193581  \
# userId                   ...
# 1           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# ...         ...     ...  ...     ...     ...     ...     ...     ...     ...
# 606         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 607         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 608         NaN     4.0  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 609         NaN     4.0  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 610         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  193583  193585  193587  193609
# userId
# 1           NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN
# 5           NaN     NaN     NaN     NaN
# ...         ...     ...     ...     ...
# 606         NaN     NaN     NaN     NaN
# 607         NaN     NaN     NaN     NaN
# 608         NaN     NaN     NaN     NaN
# 609         NaN     NaN     NaN     NaN
# 610         NaN     NaN     NaN     NaN
#
# [610 rows x 9724 columns]

# %%
# load the movie titles and genres into a dataframe
movie_genre = pd.read_csv("./data/ml-latest-small/movies.csv",index_col=1,)
# change index from title to movieId
movie_genre.reset_index(inplace=True)
movie_genre.set_index('movieId',inplace=True)

# %%
# Merge the dataframes on movieId and subsitute movieId with movie title
user_item = pd.merge(movie_genre, user_item_init.T, left_index=True, right_index=True)
user_item.drop('genres', inplace=True, axis=1)
user_item.reset_index(inplace=True, drop=True)
user_item = user_item.set_index('title').T
user_item.index.name = 'userId'
user_item.head(5)
# Out:
# title   Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# userId
# 1                    4.0             NaN                      4.0
# 2                    NaN             NaN                      NaN
# 3                    NaN             NaN                      NaN
# 4                    NaN             NaN                      NaN
# 5                    4.0             NaN                      NaN
#
# title   Waiting to Exhale (1995)  Father of the Bride Part II (1995)  \
# userId
# 1                            NaN                                 NaN
# 2                            NaN                                 NaN
# 3                            NaN                                 NaN
# 4                            NaN                                 NaN
# 5                            NaN                                 NaN
#
# title   Heat (1995)  Sabrina (1995)  Tom and Huck (1995)  Sudden Death (1995)  \
# userId
# 1               4.0             NaN                  NaN                  NaN
# 2               NaN             NaN                  NaN                  NaN
# 3               NaN             NaN                  NaN                  NaN
# 4               NaN             NaN                  NaN                  NaN
# 5               NaN             NaN                  NaN                  NaN
#
# title   GoldenEye (1995)  ...  Gintama: The Movie (2010)  \
# userId                    ...
# 1                    NaN  ...                        NaN
# 2                    NaN  ...                        NaN
# 3                    NaN  ...                        NaN
# 4                    NaN  ...                        NaN
# 5                    NaN  ...                        NaN
#
# title   anohana: The Flower We Saw That Day - The Movie (2013)  \
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
#
# title   Silver Spoon (2014)  Love Live! The School Idol Movie (2015)  \
# userId
# 1                       NaN                                      NaN
# 2                       NaN                                      NaN
# 3                       NaN                                      NaN
# 4                       NaN                                      NaN
# 5                       NaN                                      NaN
#
# title   Jon Stewart Has Left the Building (2015)  \
# userId
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
#
# title   Black Butler: Book of the Atlantic (2017)  \
# userId
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
#
# title   No Game No Life: Zero (2017)  Flint (2017)  \
# userId
# 1                                NaN           NaN
# 2                                NaN           NaN
# 3                                NaN           NaN
# 4                                NaN           NaN
# 5                                NaN           NaN
#
# title   Bungo Stray Dogs: Dead Apple (2018)  \
# userId
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
#
# title   Andrew Dice Clay: Dice Rules (1991)
# userId
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
#
# [5 rows x 9724 columns]

# %% [markdown]
# ### 2.2 delete all movies with less than 20 votes

# %%
# define mask with all movieIds having at least 20 votes
mask_at_least_20_evals = user_item.notna().sum() >= 20
# drop these user Ids (within the transposed dataframe (with movieId as index))
user_item = user_item.T.drop(user_item.T.loc[~mask_at_least_20_evals].index).T
user_item
# Out:
# title   Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# userId
# 1                    4.0             NaN                      4.0
# 2                    NaN             NaN                      NaN
# 3                    NaN             NaN                      NaN
# 4                    NaN             NaN                      NaN
# 5                    4.0             NaN                      NaN
# ...                  ...             ...                      ...
# 606                  2.5             NaN                      NaN
# 607                  4.0             NaN                      NaN
# 608                  2.5             2.0                      2.0
# 609                  3.0             NaN                      NaN
# 610                  5.0             NaN                      NaN
#
# title   Father of the Bride Part II (1995)  Heat (1995)  Sabrina (1995)  \
# userId
# 1                                      NaN          4.0             NaN
# 2                                      NaN          NaN             NaN
# 3                                      NaN          NaN             NaN
# 4                                      NaN          NaN             NaN
# 5                                      NaN          NaN             NaN
# ...                                    ...          ...             ...
# 606                                    NaN          NaN             2.5
# 607                                    NaN          NaN             NaN
# 608                                    NaN          NaN             NaN
# 609                                    NaN          NaN             NaN
# 610                                    NaN          5.0             NaN
#
# title   GoldenEye (1995)  American President, The (1995)  Casino (1995)  \
# userId
# 1                    NaN                             NaN            NaN
# 2                    NaN                             NaN            NaN
# 3                    NaN                             NaN            NaN
# 4                    NaN                             NaN            NaN
# 5                    NaN                             NaN            NaN
# ...                  ...                             ...            ...
# 606                  NaN                             2.5            NaN
# 607                  NaN                             3.0            NaN
# 608                  4.0                             NaN            4.5
# 609                  4.0                             NaN            NaN
# 610                  NaN                             NaN            4.5
#
# title   Sense and Sensibility (1995)  ...  Captain America: Civil War (2016)  \
# userId                                ...
# 1                                NaN  ...                                NaN
# 2                                NaN  ...                                NaN
# 3                                NaN  ...                                NaN
# 4                                NaN  ...                                NaN
# 5                                NaN  ...                                NaN
# ...                              ...  ...                                ...
# 606                              4.0  ...                                NaN
# 607                              NaN  ...                                NaN
# 608                              NaN  ...                                NaN
# 609                              NaN  ...                                NaN
# 610                              NaN  ...                                5.0
#
# title   Doctor Strange (2016)  The Martian (2015)  Inside Out (2015)  \
# userId
# 1                         NaN                 NaN                NaN
# 2                         NaN                 NaN                NaN
# 3                         NaN                 NaN                NaN
# 4                         NaN                 NaN                NaN
# 5                         NaN                 NaN                NaN
# ...                       ...                 ...                ...
# 606                       NaN                 NaN                NaN
# 607                       NaN                 NaN                NaN
# 608                       NaN                 NaN                NaN
# 609                       NaN                 NaN                NaN
# 610                       3.5                 3.5                3.5
#
# title   The Revenant (2015)  Big Short, The (2015)  Zootopia (2016)  \
# userId
# 1                       NaN                    NaN              NaN
# 2                       NaN                    NaN              NaN
# 3                       NaN                    NaN              NaN
# 4                       NaN                    NaN              NaN
# 5                       NaN                    NaN              NaN
# ...                     ...                    ...              ...
# 606                     NaN                    NaN              NaN
# 607                     NaN                    NaN              NaN
# 608                     NaN                    NaN              NaN
# 609                     NaN                    NaN              NaN
# 610                     4.5                    4.0              4.0
#
# title   Arrival (2016)  Rogue One: A Star Wars Story (2016)  Logan (2017)
# userId
# 1                  NaN                                  NaN           NaN
# 2                  NaN                                  NaN           NaN
# 3                  NaN                                  NaN           NaN
# 4                  NaN                                  NaN           NaN
# 5                  NaN                                  NaN           NaN
# ...                ...                                  ...           ...
# 606                NaN                                  NaN           NaN
# 607                NaN                                  NaN           NaN
# 608                NaN                                  NaN           NaN
# 609                NaN                                  NaN           NaN
# 610                5.0                                  4.0           5.0
#
# [610 rows x 1295 columns]

# %% [markdown]
# ### 2.3 Fill the NaN by average of movie

# %%
user_item_f = user_item.fillna(user_item.mean())
user_item_f.head(5)
# Out:
# title   Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# userId
# 1                4.00000        3.431818                 4.000000
# 2                3.92093        3.431818                 3.259615
# 3                3.92093        3.431818                 3.259615
# 4                3.92093        3.431818                 3.259615
# 5                4.00000        3.431818                 3.259615
#
# title   Father of the Bride Part II (1995)  Heat (1995)  Sabrina (1995)  \
# userId
# 1                                 3.071429     4.000000        3.185185
# 2                                 3.071429     3.946078        3.185185
# 3                                 3.071429     3.946078        3.185185
# 4                                 3.071429     3.946078        3.185185
# 5                                 3.071429     3.946078        3.185185
#
# title   GoldenEye (1995)  American President, The (1995)  Casino (1995)  \
# userId
# 1               3.496212                        3.671429       3.926829
# 2               3.496212                        3.671429       3.926829
# 3               3.496212                        3.671429       3.926829
# 4               3.496212                        3.671429       3.926829
# 5               3.496212                        3.671429       3.926829
#
# title   Sense and Sensibility (1995)  ...  Captain America: Civil War (2016)  \
# userId                                ...
# 1                           3.776119  ...                           3.613636
# 2                           3.776119  ...                           3.613636
# 3                           3.776119  ...                           3.613636
# 4                           3.776119  ...                           3.613636
# 5                           3.776119  ...                           3.613636
#
# title   Doctor Strange (2016)  The Martian (2015)  Inside Out (2015)  \
# userId
# 1                    3.704545                 4.0           3.813953
# 2                    3.704545                 4.0           3.813953
# 3                    3.704545                 4.0           3.813953
# 4                    3.704545                 4.0           3.813953
# 5                    3.704545                 4.0           3.813953
#
# title   The Revenant (2015)  Big Short, The (2015)  Zootopia (2016)  \
# userId
# 1                  3.903226               3.961538         3.890625
# 2                  3.903226               3.961538         3.890625
# 3                  3.903226               3.961538         3.890625
# 4                  3.903226               3.961538         3.890625
# 5                  3.903226               3.961538         3.890625
#
# title   Arrival (2016)  Rogue One: A Star Wars Story (2016)  Logan (2017)
# userId
# 1             3.980769                             3.925926          4.28
# 2             3.980769                             3.925926          4.28
# 3             3.980769                             3.925926          4.28
# 4             3.980769                             3.925926          4.28
# 5             3.980769                             3.925926          4.28
#
# [5 rows x 1295 columns]

# %% [markdown]
# ## 3. NMF Model (non negative matrix factorization)

# %% [markdown]
# ### 3.1 instantiate and fit the nmf model

# %%
# create a model with 5 hidden features
comp = 5
nmf_model = NMF(n_components=comp, init='nndsvd',max_iter=1000)
nmf_model.fit(user_item_f)
# Out:
# /home/thorsten/anaconda3/lib/python3.9/site-packages/sklearn/decomposition/_nmf.py:1637: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# NMF(init='nndsvd', max_iter=1000, n_components=5)

# %% [markdown]
# ### 3.2 get Q and P matrices

# %%
# Q is the upper part (hidden features, movies)
comp_names = ['nmf_' + str(i + 1) for i in range(comp)]
Q_df = pd.DataFrame(data=nmf_model.components_,
            columns=nmf_model.feature_names_in_,
            index=comp_names)
Q_df
# Out:
#        Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# nmf_1          1.115864        1.045576                 1.187293
# nmf_2          1.948087        1.737447                 1.266723
# nmf_3          1.100492        0.558567                 0.285312
# nmf_4          0.057465        0.144908                 0.000000
# nmf_5          0.200326        0.104358                 0.197219
#
#        Father of the Bride Part II (1995)  Heat (1995)  Sabrina (1995)  \
# nmf_1                            1.200603     1.395424        1.325360
# nmf_2                            0.940808     1.082880        0.503647
# nmf_3                            0.000000     0.543170        0.074504
# nmf_4                            0.099286     0.168901        0.077618
# nmf_5                            0.126608     0.163216        0.159202
#
#        GoldenEye (1995)  American President, The (1995)  Casino (1995)  \
# nmf_1          1.172093                        1.362960       1.738081
# nmf_2          1.790700                        1.009188       0.012528
# nmf_3          0.127497                        0.158252       0.144101
# nmf_4          0.218451                        0.217756       0.117131
# nmf_5          0.000000                        0.127930       0.166181
#
#        Sense and Sensibility (1995)  ...  Captain America: Civil War (2016)  \
# nmf_1                      1.723023  ...                           1.367437
# nmf_2                      0.154590  ...                           0.446524
# nmf_3                      0.057991  ...                           0.434820
# nmf_4                      0.095909  ...                           0.234454
# nmf_5                      0.012772  ...                           0.112701
#
#        Doctor Strange (2016)  The Martian (2015)  Inside Out (2015)  \
# nmf_1               1.459187            1.653286           1.426664
# nmf_2               0.397025            0.174274           0.496493
# nmf_3               0.322479            0.239600           0.535813
# nmf_4               0.213194            0.239199           0.227884
# nmf_5               0.129364            0.129766           0.126309
#
#        The Revenant (2015)  Big Short, The (2015)  Zootopia (2016)  \
# nmf_1             1.535709               1.635227         1.447430
# nmf_2             0.256155               0.208502         0.490056
# nmf_3             0.588186               0.319937         0.647712
# nmf_4             0.162870               0.178532         0.208665
# nmf_5             0.149758               0.153447         0.123902
#
#        Arrival (2016)  Rogue One: A Star Wars Story (2016)  Logan (2017)
# nmf_1        1.661789                             1.526482      1.755222
# nmf_2        0.296245                             0.431400      0.305398
# nmf_3        0.177033                             0.311842      0.316759
# nmf_4        0.184012                             0.275636      0.195224
# nmf_5        0.154971                             0.123673      0.171230
#
# [5 rows x 1295 columns]

# %%
# P is the left part (users, hidden features)
P = nmf_model.transform(user_item_f)
P.shape
# Out:
# (610, 5)

# %% [markdown]
# ### 3.3 reconstruct the R matrix

# %%
# the R matrix is the dot product of P x Q
print(Q_df.shape, P.shape) # check shape for the order of the dot product
R_hat_mat = np.dot(P, Q_df)
# put R into a dataframe
R_hat_df = pd.DataFrame(data=R_hat_mat, columns=Q_df.columns, index=user_item_f.index)
R_hat_df
# Out:
# (5, 1295) (610, 5)
#         Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# userId
# 1               4.310252        3.633759                 3.551461
# 2               3.908560        3.431106                 3.258528
# 3               3.883391        3.410982                 3.211593
# 4               3.745718        3.372343                 3.275548
# 5               3.880008        3.404407                 3.244957
# ...                  ...             ...                      ...
# 606             3.870102        3.277825                 3.224671
# 607             4.025934        3.558814                 3.370001
# 608             3.186689        2.998627                 2.402751
# 609             3.843733        3.383623                 3.216619
# 610             4.341901        3.604303                 3.314503
#
#         Father of the Bride Part II (1995)  Heat (1995)  Sabrina (1995)  \
# userId
# 1                                 3.202146     4.126291        3.327446
# 2                                 3.076697     3.944379        3.187741
# 3                                 3.039420     3.922482        3.144653
# 4                                 3.139247     3.886982        3.231780
# 5                                 3.066721     3.929847        3.187144
# ...                                    ...          ...             ...
# 606                               2.990410     3.912328        3.200415
# 607                               3.162993     3.991562        3.222631
# 608                               2.628132     3.730358        2.822281
# 609                               3.055637     3.921788        3.179073
# 610                               3.008955     4.141471        3.183544
#
#         GoldenEye (1995)  American President, The (1995)  Casino (1995)  \
# userId
# 1               3.555005                        3.752819       4.032919
# 2               3.504125                        3.678165       3.928116
# 3               3.463670                        3.664168       3.865624
# 4               3.540688                        3.698896       3.958689
# 5               3.480236                        3.662418       3.941014
# ...                  ...                             ...            ...
# 606             3.217995                        3.571947       4.024213
# 607             3.676437                        3.736780       3.906264
# 608             3.199926                        3.570850       3.805887
# 609             3.462402                        3.664857       3.938364
# 610             3.468179                        3.679801       3.995071
#
#         Sense and Sensibility (1995)  ...  Captain America: Civil War (2016)  \
# userId                                ...
# 1                           3.810671  ...                           3.659978
# 2                           3.776355  ...                           3.615017
# 3                           3.659759  ...                           3.603085
# 4                           3.831316  ...                           3.558351
# 5                           3.798913  ...                           3.610137
# ...                              ...  ...                                ...
# 606                         3.779618  ...                           3.619410
# 607                         3.818991  ...                           3.593857
# 608                         3.615626  ...                           3.877089
# 609                         3.776701  ...                           3.619566
# 610                         3.828970  ...                           3.798060
#
#         Doctor Strange (2016)  The Martian (2015)  Inside Out (2015)  \
# userId
# 1                    3.762872            4.023191           3.888723
# 2                    3.707077            4.003912           3.813012
# 3                    3.685978            3.975220           3.797805
# 4                    3.681525            3.997525           3.738027
# 5                    3.704671            4.007059           3.808125
# ...                       ...                 ...                ...
# 606                  3.718987            4.034073           3.833506
# 607                  3.691831            3.969001           3.791219
# 608                  3.860561            4.261410           4.038911
# 609                  3.712257            4.019232           3.814714
# 610                  3.834929            4.103874           4.045039
#
#         The Revenant (2015)  Big Short, The (2015)  Zootopia (2016)  \
# userId
# 1                  4.025917               4.048768         3.988775
# 2                  3.898964               3.962348         3.887039
# 3                  3.861966               3.923265         3.863092
# 4                  3.819589               3.945260         3.789807
# 5                  3.903221               3.967165         3.884482
# ...                     ...                    ...              ...
# 606                3.995220               4.027173         3.929608
# 607                3.861712               3.935117         3.863683
# 608                3.997137               4.029019         4.084097
# 609                3.902275               3.970651         3.886142
# 610                4.177708               4.103078         4.181551
#
#         Arrival (2016)  Rogue One: A Star Wars Story (2016)  Logan (2017)
# userId
# 1             4.058465                             3.943867      4.378476
# 2             3.984377                             3.930655      4.281573
# 3             3.944991                             3.921520      4.242509
# 4             4.002209                             3.903542      4.270695
# 5             3.987220                             3.925070      4.284496
# ...                ...                                  ...           ...
# 606           4.015747                             3.915908      4.337016
# 607           3.974924                             3.907562      4.260466
# 608           3.985141                             4.247454      4.318644
# 609           3.991349                             3.940562      4.288485
# 610           4.044432                             4.046868      4.411662
#
# [610 rows x 1295 columns]

# %% [markdown]
# ### 3.4 calculate the reconstructed error between R und R-hat

# %%
# model knows the original R matrix as it was input to the model
nmf_model.reconstruction_err_
# Out:
# 224.010944599133

# %%
# different reconstruction error by manual calculation
np.sqrt(((np.square(user_item_f - R_hat_mat)).sum()).sum())
# Out:
# 224.0119214246648

# %% [markdown]
# ### 3.5 compare the 2 R matrices and save the model

# %%
user_item_f.head(2)
# Out:
# title   Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# userId
# 1                4.00000        3.431818                 4.000000
# 2                3.92093        3.431818                 3.259615
#
# title   Father of the Bride Part II (1995)  Heat (1995)  Sabrina (1995)  \
# userId
# 1                                 3.071429     4.000000        3.185185
# 2                                 3.071429     3.946078        3.185185
#
# title   GoldenEye (1995)  American President, The (1995)  Casino (1995)  \
# userId
# 1               3.496212                        3.671429       3.926829
# 2               3.496212                        3.671429       3.926829
#
# title   Sense and Sensibility (1995)  ...  Captain America: Civil War (2016)  \
# userId                                ...
# 1                           3.776119  ...                           3.613636
# 2                           3.776119  ...                           3.613636
#
# title   Doctor Strange (2016)  The Martian (2015)  Inside Out (2015)  \
# userId
# 1                    3.704545                 4.0           3.813953
# 2                    3.704545                 4.0           3.813953
#
# title   The Revenant (2015)  Big Short, The (2015)  Zootopia (2016)  \
# userId
# 1                  3.903226               3.961538         3.890625
# 2                  3.903226               3.961538         3.890625
#
# title   Arrival (2016)  Rogue One: A Star Wars Story (2016)  Logan (2017)
# userId
# 1             3.980769                             3.925926          4.28
# 2             3.980769                             3.925926          4.28
#
# [2 rows x 1295 columns]

# %%
R_hat_df.head(2)
# Out:
#         Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# userId
# 1               4.310252        3.633759                 3.551461
# 2               3.908560        3.431106                 3.258528
#
#         Father of the Bride Part II (1995)  Heat (1995)  Sabrina (1995)  \
# userId
# 1                                 3.202146     4.126291        3.327446
# 2                                 3.076697     3.944379        3.187741
#
#         GoldenEye (1995)  American President, The (1995)  Casino (1995)  \
# userId
# 1               3.555005                        3.752819       4.032919
# 2               3.504125                        3.678165       3.928116
#
#         Sense and Sensibility (1995)  ...  Captain America: Civil War (2016)  \
# userId                                ...
# 1                           3.810671  ...                           3.659978
# 2                           3.776355  ...                           3.615017
#
#         Doctor Strange (2016)  The Martian (2015)  Inside Out (2015)  \
# userId
# 1                    3.762872            4.023191           3.888723
# 2                    3.707077            4.003912           3.813012
#
#         The Revenant (2015)  Big Short, The (2015)  Zootopia (2016)  \
# userId
# 1                  4.025917               4.048768         3.988775
# 2                  3.898964               3.962348         3.887039
#
#         Arrival (2016)  Rogue One: A Star Wars Story (2016)  Logan (2017)
# userId
# 1             4.058465                             3.943867      4.378476
# 2             3.984377                             3.930655      4.281573
#
# [2 rows x 1295 columns]

# %%
# save the model with pickle
with open('nmf_model.pkl', mode='wb') as file:
    pickle.dump(nmf_model, file)

# %% [markdown]
# ## 4. Create recommandations for a new user

# %% [markdown]
# ### 4.1 new user query

# %%
# New user has to enter some ratings to enable a prediction
new_user_query = {"Toy Story (1995)": 5,
                 "Ace Ventura: When Nature Calls (1995)":5,
                 "Get Shorty (1995)":5}

# %% [markdown]
# ### 4.2 buidling R matrix for new user

# %%
# get a list containing all movies
movies = user_item_f.columns.to_list()

# %%
# create dataframe for this user
df_user = pd.DataFrame(data=new_user_query,
                            index=['new_user'],
                            columns=movies)
df_user
# Out:
#           Toy Story (1995) Jumanji (1995) Grumpier Old Men (1995)  \
# new_user                 5            NaN                     NaN
#
#          Father of the Bride Part II (1995) Heat (1995) Sabrina (1995)  \
# new_user                                NaN         NaN            NaN
#
#          GoldenEye (1995) American President, The (1995) Casino (1995)  \
# new_user              NaN                            NaN           NaN
#
#          Sense and Sensibility (1995)  ... Captain America: Civil War (2016)  \
# new_user                          NaN  ...                               NaN
#
#           Doctor Strange (2016)  The Martian (2015) Inside Out (2015)  \
# new_user                    NaN                 NaN               NaN
#
#          The Revenant (2015) Big Short, The (2015) Zootopia (2016)  \
# new_user                 NaN                   NaN             NaN
#
#          Arrival (2016) Rogue One: A Star Wars Story (2016) Logan (2017)
# new_user            NaN                                 NaN          NaN
#
# [1 rows x 1295 columns]

# %%
# fill the NaN with the original mean
df_user_imp = df_user.fillna(user_item_f.mean())
df_user_imp
# Out:
#           Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# new_user                 5        3.431818                 3.259615
#
#           Father of the Bride Part II (1995)  Heat (1995)  Sabrina (1995)  \
# new_user                            3.071429     3.946078        3.185185
#
#           GoldenEye (1995)  American President, The (1995)  Casino (1995)  \
# new_user          3.496212                        3.671429       3.926829
#
#           Sense and Sensibility (1995)  ...  \
# new_user                      3.776119  ...
#
#           Captain America: Civil War (2016)  Doctor Strange (2016)  \
# new_user                           3.613636               3.704545
#
#           The Martian (2015)  Inside Out (2015)  The Revenant (2015)  \
# new_user                 4.0           3.813953             3.903226
#
#           Big Short, The (2015)  Zootopia (2016)  Arrival (2016)  \
# new_user               3.961538         3.890625        3.980769
#
#           Rogue One: A Star Wars Story (2016)  Logan (2017)
# new_user                             3.925926          4.28
#
# [1 rows x 1295 columns]

# %% [markdown]
# ### 4.3 get the user's P matrix

# %%
new_user_matrix = nmf_model.transform(df_user_imp)
new_user_matrix
# Out:
# array([[2.06098612, 0.41859773, 0.56920256, 1.21639739, 0.68233803]])

# %% [markdown]
# ### 4.4 calculate R hat for the user

# %%
# The Q matrix doesn't depend on the user but only on the movies
R_hat_new_user = np.dot(new_user_matrix, Q_df)
R_hat_new_user_df = pd.DataFrame(data=R_hat_new_user, index=['new_user'], columns=movies) 
R_hat_new_user_df
# Out:
#           Toy Story (1995)  Jumanji (1995)  Grumpier Old Men (1995)  \
# new_user          3.948237         3.44762                 3.274211
#
#           Father of the Bride Part II (1995)  Heat (1995)  Sabrina (1995)  \
# new_user                            3.075408     3.955233        3.187825
#
#           GoldenEye (1995)  American President, The (1995)  Casino (1995)  \
# new_user          3.503545                        3.673732       3.925296
#
#           Sense and Sensibility (1995)  ...  \
# new_user                      3.774225  ...
#
#           Captain America: Civil War (2016)  Doctor Strange (2016)  \
# new_user                           3.614771               3.704713
#
#           The Martian (2015)  Inside Out (2015)  The Revenant (2015)  \
# new_user            3.996236           3.816533             3.907399
#
#           Big Short, The (2015)  Zootopia (2016)  Arrival (2016)  \
# new_user               3.961437         3.895311        3.979273
#
#           Rogue One: A Star Wars Story (2016)  Logan (2017)
# new_user                             3.923814      4.279934
#
# [1 rows x 1295 columns]

# %% [markdown]
# ### 4.5 create recommendations for new user

# %%
# create a list of movies the user has already seen
seen = list(new_user_query.keys())
# set these movies to 0 (to avoid there recommendation)
R_hat_trans = R_hat_new_user_df.T.reset_index()
mask = R_hat_trans['index'].isin(seen)
R_hat_trans['new_user'].loc[mask] = 0
R_hat_trans.set_index('index', inplace=True)
# sort the movies by rating and show the top 10
R_hat_trans.sort_values(by=['new_user'], ascending=False).head(10)
# Out:
# /tmp/ipykernel_11958/2953591743.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   R_hat_trans['new_user'].loc[mask] = 0
#                                                new_user
# index
# Streetcar Named Desire, A (1951)               4.471072
# Shawshank Redemption, The (1994)               4.454232
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)  4.329663
# Godfather, The (1972)                          4.310740
# Philadelphia Story, The (1940)                 4.305761
# Fight Club (1999)                              4.302067
# Lawrence of Arabia (1962)                      4.300344
# In the Name of the Father (1993)               4.299219
# Hoop Dreams (1994)                             4.292765
# Harold and Maude (1971)                        4.287868

# %% [markdown]
# ## 5. create recommendation with a NMF recommender function

# %%
def recommend_nmf(query, model, k=10):
    """
    Filters and recommends the top k movies for any given input query based on a trained NMF model. 
    Returns a list of k movie ids.
    """
    # 1. candidate generation (construct new_user-item dataframe given the query)
    # create dataframe for this user
    df_user = pd.DataFrame(data=query,
                                index=['new_user'],
                                columns=movies)
    # fill the dataframe with the mean of filled ratings (orig)
    df_user_imp = df_user.fillna(user_item_f.mean())

    # 2. scoring (calculate the score with the NMF model)
    # get the users P matrix
    new_user_mat = nmf_model.transform(df_user_imp) 
    # create the names of the features from the dimension of the user P-matrix
    comp_names = ['lmn_' + str(i) for i in range(new_user_mat.shape[1])]
    Q_df = pd.DataFrame(data=model.components_,
            columns=model.feature_names_in_,
            index= comp_names)
    R_hat_new_user_df = pd.DataFrame(data=np.dot(new_user_mat, Q_df), index=['new_user'], columns=movies)
    
    # 3. ranking (get the sorting of films for the user but exclude the ones he has already seen)
    seen = list(query.keys())
    # set movies all ready seen by the user to 0 
    R_hat_trans = R_hat_new_user_df.T.reset_index()
    mask = R_hat_trans['index'].isin(seen)
    R_hat_trans['new_user'].loc[mask] = 0
    R_hat_trans.set_index('index', inplace=True)
    
    # return the top-k highest rated movie ids or titles
    return R_hat_trans.sort_values(by=['new_user'], ascending=False).head(k)

# %%
# query
new_user_query = {"Toy Story (1995)": 5,
                 "Ace Ventura: When Nature Calls (1995)":5,
                 "Get Shorty (1995)":5}
recommend_nmf(new_user_query, nmf_model, k=10)
# Out:
# /tmp/ipykernel_4563/2555928130.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   R_hat_trans['new_user'].loc[mask] = 0
#                                                new_user
# index
# Streetcar Named Desire, A (1951)               4.471071
# Shawshank Redemption, The (1994)               4.454238
# Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)  4.329662
# Godfather, The (1972)                          4.310746
# Philadelphia Story, The (1940)                 4.305759
# Fight Club (1999)                              4.302077
# Lawrence of Arabia (1962)                      4.300341
# In the Name of the Father (1993)               4.299218
# Hoop Dreams (1994)                             4.292764
# Harold and Maude (1971)                        4.287867

# %%
# save csv file for user_item_matrix for latter usage
user_item_f.to_csv('user_item.csv')
